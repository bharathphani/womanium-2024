# %% [markdown]
# ## Import pennylane and tensorflow

# %%
! ls ./QCNN/data/qcnn/
# Out:
# q_test_images.npy  q_train_images.npy

# %%
import pennylane as qml
from pennylane import numpy as np
from pennylane.templates import RandomLayers
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt

# %% [markdown]
# ## Set hyperparameters

# %%
n_epochs = 30   # Number of optimization epochs
n_layers = 1    # Number of random layers
n_train = 50    # Size of the train dataset
n_test = 30     # Size of the test dataset

SAVE_PATH = "./QCNN/data/qcnn/"  # Data saving folder
PREPROCESS = True           # If False, skip quantum processing and load data from SAVE_PATH
np.random.seed(0)           # Seed for NumPy random number generator
tf.random.set_seed(0)       # Seed for TensorFlow random number generator

# %% [markdown]
# ## load Minist dataset

# %%
mnist_dataset = keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist_dataset.load_data()

# Reduce dataset size
train_images = train_images[:n_train]
train_labels = train_labels[:n_train]
test_images = test_images[:n_test]
test_labels = test_labels[:n_test]

# Normalize pixel values within 0 and 1
train_images = train_images / 255
test_images = test_images / 255

# Add extra dimension for convolution channels
train_images = np.array(train_images[..., tf.newaxis], requires_grad=False)
test_images = np.array(test_images[..., tf.newaxis], requires_grad=False)

# %% [markdown]
# ## Quantum circuit as a convolution kernel
# https://pennylane.ai/qml/demos/tutorial_quanvolution/

# %%
dev = qml.device("default.qubit", wires=4)
# Random circuit parameters
rand_params = np.random.uniform(high=2 * np.pi, size=(n_layers, 4))

@qml.qnode(dev)
def circuit(phi):
    # Encoding of 4 classical input values
    for j in range(4):
        qml.RY(np.pi * phi[j], wires=j)

    # Random quantum circuit
    RandomLayers(rand_params, wires=list(range(4)))

    # Measurement producing 4 classical output values
    return [qml.expval(qml.PauliZ(j)) for j in range(4)]

# %% [markdown]
# The next function defines the convolution scheme:
# the image is divided into squares of  2×2 pixels;
# each square is processed by the quantum circuit;
# the 4 expectation values are mapped into 4 different channels of a single output pixel.

# %%
def quanv(image):
    """Convolves the input image with many applications of the same quantum circuit."""
    out = np.zeros((14, 14, 4))

    # Loop over the coordinates of the top-left pixel of 2X2 squares
    for j in range(0, 28, 2):
        for k in range(0, 28, 2):
            # Process a squared 2x2 region of the image with a quantum circuit
            q_results = circuit(
                [
                    image[j, k, 0],
                    image[j, k + 1, 0],
                    image[j + 1, k, 0],
                    image[j + 1, k + 1, 0]
                ]
            )
            # Assign expectation values to different channels of the output pixel (j/2, k/2)
            for c in range(4):
                out[j // 2, k // 2, c] = q_results[c]
    return out

# %% [markdown]
# ## Quantum pre-processing of the dataset

# %%
if PREPROCESS == True:
    q_train_images = []
    print("Quantum pre-processing of train images:")
    for idx, img in enumerate(train_images):
        print("{}/{}        ".format(idx + 1, n_train), end="\r")
        q_train_images.append(quanv(img))
    q_train_images = np.asarray(q_train_images)
    print(q_train_images[:1])
    q_test_images = []
    print("\nQuantum pre-processing of test images:")
    for idx, img in enumerate(test_images):
        print("{}/{}        ".format(idx + 1, n_test), end="\r")
        q_test_images.append(quanv(img))
    q_test_images = np.asarray(q_test_images)

    print(q_test_images[:1])
    # Save pre-processed images
    
    np.save(SAVE_PATH + "q_train_images.npy", q_train_images)
    
    np.save(SAVE_PATH + "q_test_images.npy", q_test_images)


# Load pre-processed images
q_train_images = np.load(SAVE_PATH + "q_train_images.npy")
q_test_images = np.load(SAVE_PATH + "q_test_images.npy")
# Out:
# Quantum pre-processing of train images:
# [[[[ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]]
#
#   [[ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]]
#
#   [[ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.08242685 -0.81417849]
#    [ 1.         -0.8346166   0.03680702 -0.81417849]
#    [ 1.         -0.8346166   0.63570292  0.08724119]
#    [ 1.         -0.8346166   0.59023519 -0.79216378]
#    [ 1.         -0.8346166   0.61580811  0.8346166 ]
#    [ 1.         -0.8346166   0.16830809 -0.00514119]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]]
#
#   [[ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.68710058]
#    [ 0.93247223 -0.51749205  0.23634833  0.51733496]
#    [ 0.40110153  0.78940503  0.12174679 -0.7891654 ]
#    [-0.5         0.84793434  0.12174679 -0.84767695]
#    [-0.99969645  0.84793434  0.12174679 -0.84767695]
#    [-0.99969645  0.84793434  0.12174679 -0.84690494]
#    [-0.93247223  0.90509312  0.5372876   0.48120132]
#    [-0.99969645  0.9117793   0.48377511  0.70325352]
#    [-0.73900892 -0.19764822  0.20072414 -0.19764822]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]]
#
#   [[ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.69302515 -0.10606591 -0.69302515]
#    [-0.9032472   0.84793434  0.473061   -0.2916461 ]
#    [-0.99969645  0.84793434  0.59103508 -0.84767695]
#    [-0.99969645  0.84793434  0.12174679 -0.69208139]
#    [-0.76339828  0.95048672 -0.0189271   0.95048672]
#    [-0.99514692  0.91676955  0.2307548  -0.29401738]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]]
#
#   [[ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.72769596 -0.10606591 -0.72769596]
#    [ 0.99992411  0.78940503 -0.10606591 -0.11146885]
#    [-0.99969645  0.12106333  0.12174679 -0.08427629]
#    [ 1.         -0.8346166  -0.09032064 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]]
#
#   [[ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.75254402 -0.10606591 -0.75254402]
#    [-0.69613395  0.84793434  0.17020612 -0.83535288]
#    [ 0.6506183  -0.8346166   0.32929326  0.32532176]
#    [ 1.         -0.8346166   0.59421884 -0.83455326]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]]
#
#   [[ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.          0.01048109 -0.10606591  0.01048109]
#    [-0.9829731   0.84793434  0.24556453 -0.55957267]
#    [-0.99969645  0.4605726   0.12174679 -0.46043279]
#    [ 0.952942   -0.8346166   0.64245158 -0.78886612]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]]
#
#   [[ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.71057625 -0.10606591 -0.71057625]
#    [ 0.41235632  0.85440065 -0.10606591 -0.85206743]
#    [-0.99969645  0.96781495  0.12174679 -0.96517201]
#    [ 1.         -0.8346166   0.37759104 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]]
#
#   [[ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166   0.20072414  0.20855649]
#    [ 0.84366715  0.57627212  0.30148581 -0.5760972 ]
#    [-0.63171101  0.84793434  0.12174679 -0.84767695]
#    [-0.99969645  0.99996801  0.14512655 -0.62209292]
#    [ 0.99969645 -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]]
#
#   [[ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166   0.07647372 -0.57357915]
#    [ 0.95660442  0.40505623  0.40765826 -0.40493328]
#    [-0.91354546  0.84793434  0.12174679 -0.84767695]
#    [-0.99969645  0.84793434  0.12174679 -0.64731162]
#    [-0.99969645  0.99664656  0.47845437  0.99634403]
#    [ 0.57273514 -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]]
#
#   [[ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166   0.31720043  0.43498956]
#    [ 0.97551197  0.89978595  0.32241375 -0.89951282]
#    [-0.9032472   0.84793434  0.12174679 -0.84767695]
#    [-0.99969645  0.84793434  0.12174679 -0.84015984]
#    [-0.99969645  0.98788176  0.64348974  0.97882412]
#    [ 0.55236497 -0.76854038 -0.10606591 -0.76854038]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]]
#
#   [[ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [-0.10452846  0.84793434 -0.10606591  0.84793434]
#    [-0.99969645  0.84793434 -0.10606591  0.84793434]
#    [-0.862929    0.62549026 -0.10606591  0.62549026]
#    [-0.05541147 -0.71057625 -0.10606591 -0.71057625]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]]
#
#   [[ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]]]]
#
# Quantum pre-processing of test images:
# [[[[ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]]
#
#   [[ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]]
#
#   [[ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]]
#
#   [[ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166   0.49419553  0.54301684]
#    [ 1.         -0.8346166   0.63048211  0.23827602]
#    [ 1.         -0.8346166   0.35128043 -0.75386511]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]]
#
#   [[ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [-0.91848699  0.84133932  0.39672577  0.13928699]
#    [-0.99992411  0.84133932  0.42740023  0.13928699]
#    [-0.99992411  0.91676955  0.62266458 -0.86276197]
#    [-0.76339828  0.99294228  0.11391499 -0.9258911 ]
#    [-0.76339828  0.99294228  0.11391499 -0.99286692]
#    [-0.76339828  0.99294228  0.11391499 -0.99105899]
#    [-0.76339828  0.99294228  0.30148581 -0.99286692]
#    [-0.5        -0.33988807  0.11391499  0.05213599]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]]
#
#   [[ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.70185396 -0.10606591 -0.70185396]
#    [ 0.68723669 -0.72769596 -0.10606591 -0.72769596]
#    [ 0.67823512 -0.16129068 -0.10606591 -0.16129068]
#    [ 0.67823512 -0.25761984 -0.10606591 -0.25761984]
#    [ 0.9667184   0.93961919  0.48902244 -0.93933397]
#    [-0.99992411  0.31312389  0.4318827   0.3054561 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]]
#
#   [[ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.65667166 -0.10606591  0.01213457]
#    [-0.96349314  0.8346166   0.11391499 -0.81637823]
#    [ 0.52118488 -0.8346166   0.23817774 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]]
#
#   [[ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 0.74725253  0.87301769  0.64348974 -0.87295144]
#    [-0.99992411 -0.22173965  0.54492876 -0.22131908]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]]
#
#   [[ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.76854038 -0.10606591 -0.01420178]
#    [-0.81619691  0.8789596   0.11391499 -0.54681203]
#    [ 0.75538273 -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]]
#
#   [[ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.81185517]
#    [ 0.60263464  0.86073729  0.35630119 -0.86067197]
#    [-0.9829731  -0.28134749  0.61580811 -0.28134749]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]]
#
#   [[ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 0.99931706  0.99836003  0.19313745 -0.99828427]
#    [-0.99992411  0.99023817  0.11391499  0.5771015 ]
#    [ 0.90846527 -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]]
#
#   [[ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.56918746 -0.10606591  0.03853855]
#    [-0.92795109  0.84133932  0.11391499 -0.84127547]
#    [ 0.15339165 -0.82776721  0.2961664  -0.82776721]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]]
#
#   [[ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 0.73065313  0.9117793   0.62724328 -0.91171011]
#    [-0.99992411  0.84133932  0.11391499 -0.75993738]
#    [ 0.80171428 -0.8346166   0.20828037 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]]
#
#   [[ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 0.07999425  0.84133932 -0.10606591  0.84133932]
#    [-0.83018403 -0.69302515 -0.10606591 -0.69302515]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]
#    [ 1.         -0.8346166  -0.10606591 -0.8346166 ]]]]

# %% [markdown]
# ## Let us visualize the effect of the quantum convolution layer on a batch of samples:

# %%
n_samples = 4
n_channels = 4
fig, axes = plt.subplots(1 + n_channels, n_samples, figsize=(10, 10))
for k in range(n_samples):
    axes[0, 0].set_ylabel("Input")
    if k != 0:
        axes[0, k].yaxis.set_visible(False)
    axes[0, k].imshow(train_images[k, :, :, 0], cmap="gray")

    # Plot all output channels
    for c in range(n_channels):
        axes[c + 1, 0].set_ylabel("Output [ch. {}]".format(c))
        if k != 0:
            axes[c, k].yaxis.set_visible(False)
        axes[c + 1, k].imshow(q_train_images[k, :, :, c], cmap="gray")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Hybrid quantum-classical model¶

# %%
def MyModel():
    """Initializes and returns a custom Keras model
    which is ready to be trained."""
    model = keras.models.Sequential([
        keras.layers.Flatten(),
        keras.layers.Dense(10, activation="softmax")
    ])

    model.compile(
        optimizer='adam',
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"],
    )
    return model

# %% [markdown]
# ## Training

# %%
q_model = MyModel()

q_history = q_model.fit(
    q_train_images,
    train_labels,
    validation_data=(q_test_images, test_labels),
    batch_size=4,
    epochs=n_epochs,
    verbose=2,
)
# Out:
# Epoch 1/30
# 13/13 - 1s - 72ms/step - accuracy: 0.1600 - loss: 2.7526 - val_accuracy: 0.2000 - val_loss: 2.1654
# Epoch 2/30
# 13/13 - 0s - 6ms/step - accuracy: 0.2800 - loss: 1.9172 - val_accuracy: 0.2667 - val_loss: 2.0645
# Epoch 3/30
# 13/13 - 0s - 6ms/step - accuracy: 0.5200 - loss: 1.6171 - val_accuracy: 0.3333 - val_loss: 1.8856
# Epoch 4/30
# 13/13 - 0s - 6ms/step - accuracy: 0.7800 - loss: 1.2920 - val_accuracy: 0.4000 - val_loss: 1.6876
# Epoch 5/30
# 13/13 - 0s - 6ms/step - accuracy: 0.8600 - loss: 1.0596 - val_accuracy: 0.4333 - val_loss: 1.5818
# Epoch 6/30
# 13/13 - 0s - 7ms/step - accuracy: 0.9200 - loss: 0.8762 - val_accuracy: 0.4667 - val_loss: 1.4946
# Epoch 7/30
# 13/13 - 0s - 6ms/step - accuracy: 0.9200 - loss: 0.7328 - val_accuracy: 0.5333 - val_loss: 1.4150
# Epoch 8/30
# 13/13 - 0s - 7ms/step - accuracy: 0.9400 - loss: 0.6206 - val_accuracy: 0.6000 - val_loss: 1.3537
# Epoch 9/30
# 13/13 - 0s - 6ms/step - accuracy: 0.9600 - loss: 0.5296 - val_accuracy: 0.6000 - val_loss: 1.3049
# Epoch 10/30
# 13/13 - 0s - 12ms/step - accuracy: 0.9800 - loss: 0.4568 - val_accuracy: 0.6000 - val_loss: 1.2644
# Epoch 11/30
# 13/13 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.3979 - val_accuracy: 0.6000 - val_loss: 1.2303
# Epoch 12/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.3494 - val_accuracy: 0.6000 - val_loss: 1.2017
# Epoch 13/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.3091 - val_accuracy: 0.6000 - val_loss: 1.1777
# Epoch 14/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.2753 - val_accuracy: 0.6000 - val_loss: 1.1570
# Epoch 15/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.2467 - val_accuracy: 0.6000 - val_loss: 1.1393
# Epoch 16/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.2224 - val_accuracy: 0.6000 - val_loss: 1.1239
# Epoch 17/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.2016 - val_accuracy: 0.6000 - val_loss: 1.1105
# Epoch 18/30
# 13/13 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.1836 - val_accuracy: 0.6000 - val_loss: 1.0988
# Epoch 19/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.1680 - val_accuracy: 0.6000 - val_loss: 1.0884
# Epoch 20/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.1544 - val_accuracy: 0.6000 - val_loss: 1.0792
# Epoch 21/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.1425 - val_accuracy: 0.6000 - val_loss: 1.0709
# Epoch 22/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.1319 - val_accuracy: 0.6000 - val_loss: 1.0635
# Epoch 23/30
# 13/13 - 0s - 17ms/step - accuracy: 1.0000 - loss: 0.1226 - val_accuracy: 0.6000 - val_loss: 1.0569
# Epoch 24/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.1142 - val_accuracy: 0.6000 - val_loss: 1.0509
# Epoch 25/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.1067 - val_accuracy: 0.6000 - val_loss: 1.0454
# Epoch 26/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.1000 - val_accuracy: 0.6000 - val_loss: 1.0404
# Epoch 27/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.0940 - val_accuracy: 0.6000 - val_loss: 1.0359
# Epoch 28/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.0885 - val_accuracy: 0.6000 - val_loss: 1.0317
# Epoch 29/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.0835 - val_accuracy: 0.6000 - val_loss: 1.0279
# Epoch 30/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.0790 - val_accuracy: 0.6000 - val_loss: 1.0244

# %%
c_model = MyModel()

c_history = c_model.fit(
    train_images,
    train_labels,
    validation_data=(test_images, test_labels),
    batch_size=4,
    epochs=n_epochs,
    verbose=2,
)
# Out:
# Epoch 1/30
# 13/13 - 1s - 63ms/step - accuracy: 0.1000 - loss: 2.3861 - val_accuracy: 0.2333 - val_loss: 2.2753
# Epoch 2/30
# 13/13 - 0s - 6ms/step - accuracy: 0.3600 - loss: 1.9790 - val_accuracy: 0.3000 - val_loss: 2.1311
# Epoch 3/30
# 13/13 - 0s - 6ms/step - accuracy: 0.5600 - loss: 1.6939 - val_accuracy: 0.3333 - val_loss: 1.9939
# Epoch 4/30
# 13/13 - 0s - 6ms/step - accuracy: 0.8000 - loss: 1.4575 - val_accuracy: 0.4000 - val_loss: 1.8644
# Epoch 5/30
# 13/13 - 0s - 6ms/step - accuracy: 0.8400 - loss: 1.2582 - val_accuracy: 0.5000 - val_loss: 1.7500
# Epoch 6/30
# 13/13 - 0s - 6ms/step - accuracy: 0.8400 - loss: 1.0908 - val_accuracy: 0.5667 - val_loss: 1.6540
# Epoch 7/30
# 13/13 - 0s - 6ms/step - accuracy: 0.9200 - loss: 0.9508 - val_accuracy: 0.6000 - val_loss: 1.5745
# Epoch 8/30
# 13/13 - 0s - 6ms/step - accuracy: 0.9600 - loss: 0.8335 - val_accuracy: 0.6333 - val_loss: 1.5085
# Epoch 9/30
# 13/13 - 0s - 6ms/step - accuracy: 0.9800 - loss: 0.7350 - val_accuracy: 0.6667 - val_loss: 1.4530
# Epoch 10/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.6518 - val_accuracy: 0.6667 - val_loss: 1.4060
# Epoch 11/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.5811 - val_accuracy: 0.6667 - val_loss: 1.3659
# Epoch 12/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.5208 - val_accuracy: 0.7000 - val_loss: 1.3314
# Epoch 13/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.4691 - val_accuracy: 0.7000 - val_loss: 1.3016
# Epoch 14/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.4244 - val_accuracy: 0.7000 - val_loss: 1.2758
# Epoch 15/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.3856 - val_accuracy: 0.6667 - val_loss: 1.2532
# Epoch 16/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.3519 - val_accuracy: 0.6667 - val_loss: 1.2335
# Epoch 17/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.3223 - val_accuracy: 0.7000 - val_loss: 1.2160
# Epoch 18/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.2962 - val_accuracy: 0.7000 - val_loss: 1.2006
# Epoch 19/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.2732 - val_accuracy: 0.6667 - val_loss: 1.1869
# Epoch 20/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.2528 - val_accuracy: 0.6333 - val_loss: 1.1746
# Epoch 21/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.2345 - val_accuracy: 0.6667 - val_loss: 1.1637
# Epoch 22/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.2182 - val_accuracy: 0.6667 - val_loss: 1.1538
# Epoch 23/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.2036 - val_accuracy: 0.6667 - val_loss: 1.1449
# Epoch 24/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.1904 - val_accuracy: 0.6667 - val_loss: 1.1368
# Epoch 25/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.1785 - val_accuracy: 0.6667 - val_loss: 1.1294
# Epoch 26/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.1677 - val_accuracy: 0.6667 - val_loss: 1.1228
# Epoch 27/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.1579 - val_accuracy: 0.7000 - val_loss: 1.1167
# Epoch 28/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.1489 - val_accuracy: 0.7000 - val_loss: 1.1111
# Epoch 29/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.1407 - val_accuracy: 0.7000 - val_loss: 1.1060
# Epoch 30/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.1332 - val_accuracy: 0.7000 - val_loss: 1.1013

# %% [markdown]
# ## Results

# %%
import matplotlib.pyplot as plt

plt.style.use("seaborn")
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(6, 9))

ax1.plot(q_history.history["val_accuracy"], "-ob", label="With quantum layer")
ax1.plot(c_history.history["val_accuracy"], "-og", label="Without quantum layer")
ax1.set_ylabel("Accuracy")
ax1.set_ylim([0, 1])
ax1.set_xlabel("Epoch")
ax1.legend()

ax2.plot(q_history.history["val_loss"], "-ob", label="With quantum layer")
ax2.plot(c_history.history["val_loss"], "-og", label="Without quantum layer")
ax2.set_ylabel("Loss")
ax2.set_ylim(top=2.5)
ax2.set_xlabel("Epoch")
ax2.legend()
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.11/site-packages/matplotlib/style/core.py:137, in use(style)
#     136 try:
# --> 137     style = _rc_params_in_file(style)
#     138 except OSError as err:
#
# File /opt/anaconda3/lib/python3.11/site-packages/matplotlib/__init__.py:866, in _rc_params_in_file(fname, transform, fail_on_error)
#     865 rc_temp = {}
# --> 866 with _open_file_or_url(fname) as fd:
#     867     try:
#
# File /opt/anaconda3/lib/python3.11/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#
# File /opt/anaconda3/lib/python3.11/site-packages/matplotlib/__init__.py:843, in _open_file_or_url(fname)
#     842 fname = os.path.expanduser(fname)
# --> 843 with open(fname, encoding='utf-8') as f:
#     844     yield f
#
# FileNotFoundError: [Errno 2] No such file or directory: 'seaborn'
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[48], line 3
#       1 import matplotlib.pyplot as plt
# ----> 3 plt.style.use("seaborn")
#       4 fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(6, 9))
#       6 ax1.plot(q_history.history["val_accuracy"], "-ob", label="With quantum layer")
#
# File /opt/anaconda3/lib/python3.11/site-packages/matplotlib/style/core.py:139, in use(style)
#     137         style = _rc_params_in_file(style)
#     138     except OSError as err:
# --> 139         raise OSError(
#     140             f"{style!r} is not a valid package style, path of style "
#     141             f"file, URL of style file, or library style name (library "
#     142             f"styles are listed in `style.available`)") from err
#     143 filtered = {}
#     144 for k in style:  # don't trigger RcParams.__getitem__('backend')
#
# OSError: 'seaborn' is not a valid package style, path of style file, URL of style file, or library style name (library styles are listed in `style.available`)
